# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-dde22de4-fec7-4770-9173-6193dcb9f9d0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='safe', role='assistant', annotations=None, executed_tools=None, function_call=None, reasoning=None, tool_calls=None))], created=1768889738, model='meta-llama/llama-guard-4-12b', object='chat.completion', mcp_list_tools=None, service_tier='on_demand', system_fingerprint='fp_10faa87171', usage=CompletionUsage(completion_tokens=2, prompt_tokens=123, total_tokens=125, completion_time=0.006765937, completion_tokens_details=None, prompt_time=0.007953807, prompt_tokens_details=None, queue_time=0.281377542, total_time=0.014719744), usage_breakdown=None, x_groq=XGroq(id='req_01kfd0prvdejyant8v3m9x84z0', debug=None, seed=1921838496, usage=None))

# %%
from groq import Groq
import os
os.environ["GROQ_API_KEY"] = "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"
client = Groq()
response = client.chat.completions.create(
    model="meta-llama/llama-guard-4-12b",
    messages=[
        {"role": "system", "content": "You are a python programming expert."
         },
        {
            "role": "user", "content": "How python language saves a variable in memory."
        }
    ],    max_tokens=256, temperature=0.7
)
